# %% [markdown]
# # Palabras Faltantes
#
# En esta notebook, analizamos las palabras que faltaron etiquetar producto del error en el ordenamiento (Personas en vez de PalabrasPersonas)
#
# A su vez, tambien delineamos otro plan de acción:
# - Etiquetar las 1K primeras palabras de cada métrica. Medir cuál es la performance de cada una
# - Agarrar la/las mejor/es, y etiquetar sólo en base a esa métrica las 5K restantes
#
# Veamos en primer lugar cuántas palabras nos faltaron...

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
entire_df = pd.read_csv("csv/definitivo.csv")
entire_df.set_index(' ', inplace=True)
entire_df["Palabra Candidata"] = entire_df["Palabra Candidata"].astype('str')

# %%
entire_df.iloc[:10]
# Out:
#            cantPalabra  cantUsuariosTotal          regionTest  \
#
# logroño           2592                132         ['larioja']
# breñas            2590                170           ['chaco']
# oberá             4322                378        ['misiones']
# chivilcoy         4074                469     ['buenosaires']
# ush               2137                465  ['tierradelfuego']
# chivil             811                241     ['buenosaires']
# ipauss             812                 83  ['tierradelfuego']
# blv               1227                174         ['sanluis']
# sciurano           929                124  ['tierradelfuego']
# obera             2106                410        ['misiones']
#
#            provinciaSinEsaPalabra Palabra Candidata  rankPalabras  \
#
# logroño                        20                 0             5
# breñas                         17                 0             6
# oberá                           8                 0             3
# chivilcoy                       4                 0             4
# ush                             5                 0            11
# chivil                         21                 0            31
# ipauss                         22                 0            30
# blv                            15                 0            21
# sciurano                       20                 0            25
# obera                           6                 0            17
#
#            rankPalabras_Personas  rankPersonas    FnormMax   FnormMin  \
#
# logroño                        8             1  383.290488   0.111428
# breñas                         6             2  338.811866   0.108242
# oberá                          2             3  544.787250   0.100082
# chivilcoy                      1             4  444.822212   0.119363
# ush                            4             5  245.115851   0.110847
# chivil                        14             6   90.257012   0.118667
# ipauss                        39             7   94.868480  94.868480
# blv                           17             8  146.269532   0.106356
# sciurano                      25             9  108.304287   0.147989
# obera                          5            10  260.070445   0.106356
#
#                  ...         information_value_palabras  \
#                  ...
# logroño          ...                          35.431576
# breñas           ...                          35.087225
# oberá            ...                          36.329612
# chivilcoy        ...                          35.764721
# ush              ...                          33.126961
# chivil           ...                          30.074478
# ipauss           ...                          30.134664
# blv              ...                          31.457259
# sciurano         ...                          30.630563
# obera            ...                          31.857456
#
#           information_value_personas  information_value_personas_palabras  \
#
# logroño                    34.227821                             1.219112
# breñas                     32.469701                             1.239002
# oberá                      30.713960                             1.488857
# chivilcoy                  30.546287                             1.535748
# ush                        30.497203                             1.432260
# chivil                     29.707682                             1.063571
# ipauss                     29.018148                             0.740534
# blv                        28.842389                             0.994651
# sciurano                   28.582336                             0.858400
# obera                      28.439042                             1.247392
#
#                 maxDif normCantPalabras  normCantPersonas  \
#
# logroño    3439.791425         0.342184          0.377771
# breñas     3130.122229         0.342121          0.408690
# oberá      5443.422132         0.384377          0.506352
# chivilcoy  3726.627965         0.379500          0.532714
# ush        2211.300145         0.326256          0.531668
# chivil      760.590423         0.246301          0.451343
# ipauss        1.000000         0.246403          0.321068
# blv        1375.284506         0.280470          0.411533
# sciurano    731.842065         0.257511          0.370130
# obera      2445.286091         0.325050          0.516283
#
#            shuffled_entropy_palabras  shuffled_entropy_personas  Unnamed: 25  \
#
# logroño                     3.131355                   3.107384          NaN
# breñas                      3.132698                   3.096012          NaN
# oberá                       3.132531                   3.112732          NaN
# chivilcoy                   3.132428                   3.105334          NaN
# ush                         3.129223                   3.119793          NaN
# chivil                      3.121645                   3.101096          NaN
# ipauss                      3.117808                   3.002291          NaN
# blv                         3.122525                   3.057855          NaN
# sciurano                    3.123558                   2.992699          NaN
# obera                       3.130954                   3.119810          NaN
#
#                  Unnamed: 26
#
# logroño    Faltan considerar
# breñas                  4986
# oberá                    NaN
# chivilcoy                NaN
# ush                      NaN
# chivil                   NaN
# ipauss                   NaN
# blv                      NaN
# sciurano                 NaN
# obera                    NaN
#
# [10 rows x 26 columns]

# %% [markdown]
# Agarro las 5000 primeras que son las estudiadas...

# %%
df = entire_df.iloc[:5000].copy()

# %%
palabras_faltantes = set(range(1, 5001))

indices_faltantes = palabras_faltantes.difference(df.rankPalabras_Personas)

print("Faltan analizar {} palabras".format(len(indices_faltantes)))
# Out:
# Faltan analizar 1222 palabras

# %%
hist(list(indices_faltantes))
# Out:
# (array([   4.,   12.,   21.,   54.,  100.,  125.,  176.,  220.,  240.,  270.]),
#  array([  942. ,  1347.6,  1753.2,  2158.8,  2564.4,  2970. ,  3375.6,
#          3781.2,  4186.8,  4592.4,  4998. ]),
#  <a list of 10 Patch objects>)

# %%
print("De las 10K primeras palabras, faltan {}".format(len(indices_faltantes.difference(entire_df.rankPalabras_Personas))))
# Out:
# De las 10K primeras palabras, faltan 185

# %%
df.columns
# Out:
# Index([u'cantPalabra', u'cantUsuariosTotal', u'regionTest',
#        u'provinciaSinEsaPalabra', u'Palabra Candidata', u'rankPalabras',
#        u'rankPalabras_Personas', u'rankPersonas', u'FnormMax', u'FnormMin',
#        u'provinciaFnormMax', u'provinciaFnormMin', u'entropy_palabras',
#        u'entropy_personas', u'esLugar', u'fnormArgentina',
#        u'information_value_palabras', u'information_value_personas',
#        u'information_value_personas_palabras', u'maxDif', u'normCantPalabras',
#        u'normCantPersonas', u'shuffled_entropy_palabras',
#        u'shuffled_entropy_personas', u'Unnamed: 25', u'Unnamed: 26'],
#       dtype='object')

# %% [markdown]
# ## Se descartan palabras por ser "lugar"?
#
# No, hay ejemplos de lugares que fueron marcados como palabras relevantes, como vemos a continuación:

# %%
df[(df.esLugar == 'lugar') & (df["Palabra Candidata"] != '0')]
# Out:
#              cantPalabra  cantUsuariosTotal  \
#
# yuto                 188                123
# concep               248                107
# correntinos          655                246
# tolar                 45                 12
# pingo               4789               1515
# pampa               6931               1494
# huinca                74                 39
# pichincha             52                 23
# totoras              492                207
# yacimientos          106                 59
# olivares             166                 92
# gruta                155                 87
# manzano              225                124
# arenales             126                 67
# naranjos              42                 34
# balneario            868                396
# parera                93                 40
# guasa                198                145
#
#                                                     regionTest  \
#
# yuto                                        ['jujuy', 'salta']
# concep                                ['entrerios', 'tucuman']
# correntinos                            ['corrientes', 'chaco']
# tolar                                                ['salta']
# pingo        ['tucuman', 'santiago', 'salta', 'jujuy', 'cat...
# pampa                 ['lapampa', 'jujuy', 'chaco', 'mendoza']
# huinca                ['lapampa', 'cordoba', 'tierradelfuego']
# pichincha                               ['santafe', 'lapampa']
# totoras      ['santafe', 'cordoba', 'buenosaires', 'entreri...
# yacimientos  ['chubut', 'santacruz', 'neuquen', 'catamarca'...
# olivares     ['larioja', 'sanjuan', 'tucuman', 'salta', 'me...
# gruta        ['catamarca', 'sanluis', 'entrerios', 'santacr...
# manzano      ['mendoza', 'neuquen', 'larioja', 'cordoba', '...
# arenales     ['salta', 'cordoba', 'buenosaires', 'chaco', '...
# naranjos     ['entrerios', 'tierradelfuego', 'larioja', 'ju...
# balneario    ['rionegro', 'cordoba', 'neuquen', 'entrerios'...
# parera       ['lapampa', 'chaco', 'tucuman', 'santafe', 'co...
# guasa        ['entrerios', 'sanjuan', 'larioja', 'cordoba',...
#
#              provinciaSinEsaPalabra Palabra Candidata  rankPalabras  \
#
# yuto                             16                 1          1207
# concep                           13                 1          1216
# correntinos                       6                 1           449
# tolar                            21                 1          1289
# pingo                             0                 1          1627
# pampa                             0                 1           224
# huinca                           14                 1          3092
# pichincha                        15                 1          2484
# totoras                           0                 1          1951
# yacimientos                      10                 1          4294
# olivares                          6                 1          4827
# gruta                             4                 1          3858
# manzano                           2                 1          4013
# arenales                          6                 1          4724
# naranjos                         11                 1          7316
# balneario                         0                 1          4353
# parera                            7                 1          2852
# guasa                             2                 1          6965
#
#              rankPalabras_Personas  rankPersonas    FnormMax  FnormMin  \
#
# yuto                           397           492   17.305753  0.099246
# concep                         445           673   17.225007  0.116833
# correntinos                    190           730   60.757523  0.112552
# tolar                         7778          1204    5.861468  0.120090
# pingo                          417          1960  179.032889  0.949336
# pampa                          232          2110  566.009338  2.747547
# huinca                        2991          2545    4.001637  0.111428
# pichincha                     5631          2903    4.400650  0.099246
# totoras                       1038          2938   35.318034  0.120090
# yacimientos                   2753          2971    3.714232  0.111428
# olivares                      2322          2998    7.991385  0.099246
# gruta                         2123          3045    7.719350  0.106356
# manzano                       2071          3531   11.061007  0.105675
# arenales                      2962          3532    6.927189  0.110847
# naranjos                     33537          4421    1.183909  0.099246
# balneario                     1868          4499   33.727552  0.467332
# parera                        3574          4571    6.669395  0.099246
# guasa                         3363          4751    6.129144  0.110847
#
#                 ...      information_value_palabras  \
#                 ...
# yuto            ...                       15.528916
# concep          ...                       15.462245
# correntinos     ...                       19.864220
# tolar           ...                       15.136202
# pingo           ...                       13.765018
# pampa           ...                       22.540131
# huinca          ...                        9.387001
# pichincha       ...                       10.896438
# totoras         ...                       12.623315
# yacimientos     ...                        7.330358
# olivares        ...                        6.633365
# gruta           ...                        7.961174
# manzano         ...                        7.714917
# arenales        ...                        6.765023
# naranjos        ...                        4.545122
# balneario       ...                        7.242878
# parera          ...                        9.871756
# guasa           ...                        4.751117
#
#             information_value_personas  information_value_personas_palabras  \
#
# yuto                         15.347074                             0.193716
# concep                       13.940423                             0.178171
# correntinos                  13.625954                             0.320957
# tolar                        10.802594                             0.003528
# pingo                         7.703421                             0.188411
# pampa                         7.305247                             0.288756
# huinca                        6.186581                             0.016789
# pichincha                     5.515544                             0.005957
# totoras                       5.450559                             0.076351
# yacimientos                   5.384201                             0.019093
# olivares                      5.339558                             0.025073
# gruta                         5.259206                             0.028365
# manzano                       4.491982                             0.029516
# arenales                      4.489178                             0.017044
# naranjos                      3.586975                             0.000236
# balneario                     3.525177                             0.034562
# parera                        3.467819                             0.012546
# guasa                         3.344531                             0.013809
#
#                  maxDif normCantPalabras  normCantPersonas  \
#
# yuto         174.371590         0.125669          0.369140
# concep       147.432590         0.148527          0.352109
# correntinos  539.815098         0.228672          0.453853
# tolar         48.808989         0.007682          0.084713
# pingo        188.587427         0.392844          0.676019
# pampa        206.005325         0.423350          0.674313
# huinca        35.912180         0.048728          0.228762
# pichincha     44.340646         0.019613          0.164224
# totoras      294.096552         0.205058          0.432757
# yacimientos   33.332895         0.078384          0.279356
# olivares      80.520649         0.115399          0.333650
# gruta         72.580408         0.109741          0.326820
# manzano      104.670153         0.140495          0.370130
# arenales      62.493286         0.092648          0.294896
# naranjos      11.928985         0.001989          0.211994
# balneario     72.170368         0.251907          0.512037
# parera        67.200372         0.067587          0.231856
# guasa         55.293756         0.129946          0.389250
#
#              shuffled_entropy_palabras  shuffled_entropy_personas  \
#
# yuto                          3.081650                   3.025888
# concep                        3.102151                   3.080827
# correntinos                   3.110636                   3.084479
# tolar                         2.862685                   2.253858
# pingo                         3.132504                   3.125851
# pampa                         3.133873                   3.132947
# huinca                        3.028963                   2.814466
# pichincha                     2.881680                   2.449734
# totoras                       3.113056                   3.083087
# yacimientos                   3.063862                   2.971872
# olivares                      3.076732                   3.083628
# gruta                         3.058931                   2.987217
# manzano                       3.100431                   3.011916
# arenales                      3.040559                   2.925054
# naranjos                      2.908127                   2.761661
# balneario                     3.123007                   3.114240
# parera                        3.040998                   2.817859
# guasa                         3.075012                   3.036463
#
#              Unnamed: 25  Unnamed: 26
#
# yuto                 NaN          NaN
# concep               NaN          NaN
# correntinos          NaN          NaN
# tolar                NaN          NaN
# pingo                NaN          NaN
# pampa                NaN          NaN
# huinca               NaN          NaN
# pichincha            NaN          NaN
# totoras              NaN          NaN
# yacimientos          NaN          NaN
# olivares             NaN          NaN
# gruta                NaN          NaN
# manzano              NaN          NaN
# arenales             NaN          NaN
# naranjos             NaN          NaN
# balneario            NaN          NaN
# parera               NaN          NaN
# guasa                NaN          NaN
#
# [18 rows x 26 columns]

# %% [markdown]
# Palabras etiquetadas:

# %%
entire_df[entire_df["Palabra Candidata"] != 'nan'].shape
# Out:
# (5014, 26)

# %% [markdown]
# ## Porcentajes analizados de las palabras que quedan y de las que no

# %%
palabras_bien_ordenadas = entire_df[entire_df.rankPalabras_Personas <= 5000]

# %%
palabras_ya_analizadas = palabras_bien_ordenadas[palabras_bien_ordenadas["Palabra Candidata"] != 'nan']

no_candidatas = (palabras_ya_analizadas["Palabra Candidata"] != '0').sum()

print("Cantidad de palabras analizadas que 'quedan': {}".format(palabras_ya_analizadas.shape[0]))
porcentaje = no_candidatas / palabras_ya_analizadas.shape[0]
print("Porcentaje de palabras candidatas en las 3800 ya analizadas: {}".format(porcentaje * 100))
print(no_candidatas)
# Out:
# Cantidad de palabras analizadas que 'quedan': 3784
# Porcentaje de palabras candidatas en las 3800 ya analizadas: 0
# 1653

# %%
palabras_mal_analizadas = df.iloc[:5000].index.difference(palabras_ya_analizadas.index)[1:]

mal_df = df.loc[palabras_mal_analizadas]
no_candidatas = (mal_df["Palabra Candidata"] != '0').sum()

porcentaje = no_candidatas / mal_df.shape[0]
print("Cantidad de palabras analizadas que 'no quedan': {}".format(mal_df.shape[0]))
print("Porcentaje de palabras candidatas en las palabras que no debieron ser analizadas: {}".format(porcentaje*100))
print(no_candidatas)
# Out:
# Cantidad de palabras analizadas que 'no quedan': 1222
# Porcentaje de palabras candidatas en las palabras que no debieron ser analizadas: 0
# 580

# %% [markdown]
# Observamos que el porcentaje de 'candidatas' en las que vamos a tirar es mayor que en las que se quedan...esto puede ser algo producto de la variabilidad del análisis humano, o indica algún otro problema?

# %%
hist(mal_df.rankPalabras_Personas, range=(5000, 10000));

# %% [markdown]
# ## ¿Qué pasa si usamos rankPalabras?

# %%
palabras_df = entire_df[entire_df.rankPalabras <= 5000]

palabras_df.shape
# Out:
# (4039, 26)

# %%
palabras_df.columns
# Out:
# Index([u'cantPalabra', u'cantUsuariosTotal', u'regionTest',
#        u'provinciaSinEsaPalabra', u'Palabra Candidata', u'rankPalabras',
#        u'rankPalabras_Personas', u'rankPersonas', u'FnormMax', u'FnormMin',
#        u'provinciaFnormMax', u'provinciaFnormMin', u'entropy_palabras',
#        u'entropy_personas', u'esLugar', u'fnormArgentina',
#        u'information_value_palabras', u'information_value_personas',
#        u'information_value_personas_palabras', u'maxDif', u'normCantPalabras',
#        u'normCantPersonas', u'shuffled_entropy_palabras',
#        u'shuffled_entropy_personas', u'Unnamed: 25', u'Unnamed: 26'],
#       dtype='object')

# %%
candidatas = palabras_df[u"Palabra Candidata"]

hist(candidatas.as_matrix())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-6db98629b8f0> in <module>()
#       1 candidatas = palabras_df[u"Palabra Candidata"]
#       2
# ----> 3 hist(candidatas.as_matrix())
#
# /home/jmperez/.pyenv/versions/2.7.14/envs/aal/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    3080                       histtype=histtype, align=align, orientation=orientation,
#    3081                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3082                       stacked=stacked, data=data, **kwargs)
#    3083     finally:
#    3084         ax._hold = washold
#
# /home/jmperez/.pyenv/versions/2.7.14/envs/aal/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /home/jmperez/.pyenv/versions/2.7.14/envs/aal/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6190             # this will automatically overwrite bins,
#    6191             # so that each histogram uses the same bins
# -> 6192             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6193             m = m.astype(float)  # causes problems later if it's an int
#    6194             if mlast is None:
#
# /home/jmperez/.pyenv/versions/2.7.14/envs/aal/lib/python2.7/site-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     662             mn, mx = a.min() + 0.0, a.max() + 0.0
#     663     else:
# --> 664         mn, mx = [mi + 0.0 for mi in range]
#     665     if mn > mx:
#     666         raise ValueError(
#
# TypeError: cannot concatenate 'str' and 'float' objects

# %%
analizadas = palabras_df[palabras_df["Palabra Candidata"] != 'nan']

analizadas.shape
# Out:
# (3547, 26)

# %%
candidatas = (analizadas["Palabra Candidata"] != '0').sum()

print("Porcentaje de palabras candidatas: {}".format(100 * candidatas / analizadas.shape[0]))
# Out:
# Porcentaje de palabras candidatas: 34

# %% [markdown]
# ## Cambio de idea:
#
# ¿Y si primero vemos cómo dan las 3 métricas para las primeras, 1000 palabras de cada una?

# %%
from __future__ import division

palabras_faltantes = set(range(1, 1000))

faltantes_palabras = palabras_faltantes.difference(df.rankPalabras)
faltantes_palabraspersonas = palabras_faltantes.difference(df.rankPalabras_Personas)
print("Faltan analizar: {} palabras {} palabras personas".format(
    len(faltantes_palabras),
    len(faltantes_palabraspersonas),
))
# Out:
# Faltan analizar: 118 palabras 1 palabras personas

# %%
limite = 1000
df_personas = df.iloc[:limite]
df_palabras = df[df.rankPalabras <= limite] 
df_pp = df[df.rankPalabras_Personas <= limite]

# %%
pd.options.display.max_rows = 1500

def info_candidatas(df):
    
    print("="*80)
    num_candidatas = (df["Palabra Candidata"] != '0').sum()
    porcentaje = 100 * num_candidatas / df.shape[0] 
    print("{} palabras - {} candidatas - {:.2f} porcentaje".format(
        df.shape[0], num_candidatas, porcentaje
    ))
    
    palabras_afuera = df[df["Palabra Candidata"] == '0'].index 
    
    print("Palabras que quedaron afuera: {}\n\n ".format(len(palabras_afuera)))
    
    return palabras_afuera
    
    

print("Personas")
pa_personas = info_candidatas(df_personas)
print("Palabras")
pa_palabras = info_candidatas(df_palabras)
print("Palabras Personas")
pa_pp = info_candidatas(df_pp)

palabras_out = {}

for word in df_personas.index: 
    palabras_out[word] = {}
    num = entire_df.loc[word]["Palabra Candidata"].replace(",", ".")
    palabras_out[word]["personas"] = num 


for word in df_palabras.index:
    palabras_out[word] = palabras_out.get(word, {})
    num = entire_df.loc[word]["Palabra Candidata"].replace(",", ".")
    palabras_out[word]["palabras"] = num

for word in df_pp.index:
    palabras_out[word] = palabras_out.get(word, {})
    num = entire_df.loc[word]["Palabra Candidata"].replace(",", ".")
    palabras_out[word]["pp"] = num
    
df_out = pd.DataFrame(palabras_out).T


df_out.fillna("-", inplace=True)

print(df_out.shape)
# Out:
# Personas
# ================================================================================
# 1000 palabras - 246 candidatas - 24.60 porcentaje
# Palabras que quedaron afuera: 754
#
#
# Palabras
# ================================================================================
# 882 palabras - 174 candidatas - 19.73 porcentaje
# Palabras que quedaron afuera: 708
#
#
# Palabras Personas
# ================================================================================
# 999 palabras - 318 candidatas - 31.83 porcentaje
# Palabras que quedaron afuera: 681
#
#
# (1424, 3)

# %%
df_out[(df_out["palabras"] == '0') &
       (df_out["personas"] == '-') &
       (df_out["pp"] == '-') ]
# Out:
#             palabras personas pp
# acebal             0        -  -
# alhama             0        -  -
# almasana           0        -  -
# anusate            0        -  -
# arabela            0        -  -
# arnaudo            0        -  -
# aubone             0        -  -
# berti              0        -  -
# berza              0        -  -
# bianni             0        -  -
# blest              0        -  -
# brun               0        -  -
# cabot              0        -  -
# callejo            0        -  -
# calsina            0        -  -
# campiña            0        -  -
# cangrejeros        0        -  -
# capellán           0        -  -
# capsa              0        -  -
# caronte            0        -  -
# celiz              0        -  -
# chayle             0        -  -
# cinalli            0        -  -
# conlara            0        -  -
# cremería           0        -  -
# csd                0        -  -
# cst                0        -  -
# cumba              0        -  -
# cómodoro           0        -  -
# darkside           0        -  -
# ereros             0        -  -
# famaillá           0        -  -
# femad              0        -  -
# figueredo          0        -  -
# flipa              0        -  -
# garabí             0        -  -
# gardiner           0        -  -
# glaciarium         0        -  -
# gobtdf             0        -  -
# haberkorn          0        -  -
# horne              0        -  -
# iacc               0        -  -
# ibex               0        -  -
# icaño              0        -  -
# ipizca             0        -  -
# jcs                0        -  -
# juf                0        -  -
# lbd                0        -  -
# lirios             0        -  -
# lmneuquén          0        -  -
# lyder              0        -  -
# mandiyú            0        -  -
# marquesado         0        -  -
# marttu             0        -  -
# mayuatos           0        -  -
# mirolo             0        -  -
# moconá             0        -  -
# montiglio          0        -  -
# moquehuá           0        -  -
# ningo              0        -  -
# packewaia          0        -  -
# pechen             0        -  -
# polti              0        -  -
# pris               0        -  -
# qru                0        -  -
# quebraditos        0        -  -
# rebord             0        -  -
# recalt             0        -  -
# redusers           0        -  -
# regidor            0        -  -
# rosamonte          0        -  -
# rthttp             0        -  -
# sardella           0        -  -
# schonfeld          0        -  -
# senguer            0        -  -
# sensini            0        -  -
# sportmedia         0        -  -
# tajy               0        -  -
# tassano            0        -  -
# tizón              0        -  -
# trc                0        -  -
# treo               0        -  -
# ugt                0        -  -
# urresti            0        -  -
# venados            0        -  -
# vozenoff           0        -  -
# vsj                0        -  -
# vuyovich           0        -  -
# wert               0        -  -
# ycrt               0        -  -
# yerobi             0        -  -
# yesa               0        -  -
# zozo               0        -  -
# ágora              0        -  -
